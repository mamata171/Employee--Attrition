# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('Emp_EDA.csv')

# %%
df.shape
# Out:
# (1000000, 31)

# %%
df
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        58        No  Travel_Frequently        200                Hardware
# 1        18       Yes      Travel_Rarely        720                   Sales
# 2        25        No         Non-Travel       1406                 Support
# 3        38       Yes  Travel_Frequently       1316                Software
# 4        35        No      Travel_Rarely        711  Research & Development
# ...     ...       ...                ...        ...                     ...
# 999995   19       Yes      Travel_Rarely        389                   Sales
# 999996   24        No         Non-Travel       1248                Hardware
# 999997   55        No         Non-Travel       1298                 Support
# 999998   44       Yes         Non-Travel       1065  Research & Development
# 999999   19       Yes         Non-Travel        776  Research & Development
#
#         DistanceFromHome  Education    EducationField  \
# 0                     13          5     Life Sciences
# 1                     34          2  Technical Degree
# 2                      3          2     Life Sciences
# 3                     19          5             Other
# 4                     28          4  Technical Degree
# ...                  ...        ...               ...
# 999995                22          1   Human Resources
# 999996                 7          5     Life Sciences
# 999997                33          5   Human Resources
# 999998                34          3   Human Resources
# 999999                23          4   Human Resources
#
#         EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                             1    Male          33               4         5
# 1                             1  Female          50               1         1
# 2                             2  Female         198               2         4
# 3                             4    Male          38               3         2
# 4                             3    Male          90               1         5
# ...                         ...     ...         ...             ...       ...
# 999995                        2    Male         122               1         3
# 999996                        2    Male         187               3         1
# 999997                        1  Female         142               1         3
# 999998                        4  Female         102               2         1
# 999999                        1  Female         189               3         1
#
#                           JobRole  JobSatisfaction MaritalStatus  \
# 0                 Sales Executive                4       Married
# 1              Research Scientist                3        Single
# 2                 Human Resources                2      Divorced
# 3                         Manager                3        Single
# 4              Research Scientist                1        Single
# ...                           ...              ...           ...
# 999995  Healthcare Representative                3       Married
# 999996                  Developer                2      Divorced
# 999997            Sales Executive                3        Single
# 999998  Healthcare Representative                3       Married
# 999999          Research Director                2      Divorced
#
#         MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0               17288       224744                   6       No
# 1               50885      1221240                   2      Yes
# 2               16049       224686                   5      Yes
# 3               50758      1268950                   3      Yes
# 4               41000       615000                   6      Yes
# ...               ...          ...                 ...      ...
# 999995          30138       241104                   0       No
# 999996          39771      1073817                   0       No
# 999997          19790       316640                   5       No
# 999998           9736        48680                   7      Yes
# 999999          41602       249612                   1      Yes
#
#         PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                      34                  2                         2
# 1                      18                  4                         1
# 2                      48                  1                         3
# 3                      12                  4                         4
# 4                      47                  4                         4
# ...                   ...                ...                       ...
# 999995                 48                  3                         2
# 999996                 42                  2                         4
# 999997                 26                  3                         4
# 999998                 25                  3                         3
# 999999                 31                  3                         1
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                      4                 40                      3
# 1                      3                 25                      5
# 2                      4                 13                      2
# 3                      3                 29                      5
# 4                      3                  1                      1
# ...                  ...                ...                    ...
# 999995                 2                 12                      5
# 999996                 3                 32                      2
# 999997                 1                 29                      4
# 999998                 4                 20                      2
# 999999                 1                 31                      2
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                     4              31                  28
# 1                     3               8                   5
# 2                     3               5                   1
# 3                     4               5                   3
# 4                     4               1                   1
# ...                 ...             ...                 ...
# 999995                1               8                   1
# 999996                3               1                   1
# 999997                4              28                  19
# 999998                3               2                   2
# 999999                3              29                  20
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# 0                             1                    29
# 1                             4                     8
# 2                             1                     3
# 3                             1                     1
# 4                             1                     1
# ...                         ...                   ...
# 999995                        6                     2
# 999996                        1                     1
# 999997                       16                    26
# 999998                        1                     2
# 999999                       22                     7
#
# [1000000 rows x 31 columns]

# %% [markdown]
# ## Checking For Outliers

# %%
l = ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','PercentSalaryHike']

# %%
plt.figure(figsize = (18,18))
for i in range(len(l)):
    plt.subplot(4,3, i+1)
    sb.boxplot(data = df, x = df[l[i]])

# %% [markdown]
# ### DATA CLEANING

# %%
df[df['YearsAtCompany'] > df['Age']][['Age', 'YearsAtCompany']]
# Out:
#         Age  YearsAtCompany
# 8        25              27
# 22       26              29
# 96       18              19
# 98       20              27
# 133      28              30
# ...     ...             ...
# 999867   25              26
# 999893   18              19
# 999907   19              28
# 999952   26              37
# 999999   19              29
#
# [34695 rows x 2 columns]

# %% [markdown]
# Observation: From the above output it can be observed that even though the employee Age is 25 but he works 27 years at the company like this there are about 34695 rows present, that shows impossible relation between them,so we can drop them.

# %%
df.drop(df[df['YearsAtCompany']>df['Age']].index,inplace = True)

# %%
df.shape
# Out:
# (965305, 31)

# %%
df[df['TotalWorkingYears'] >= df['Age']][['TotalWorkingYears', 'Age']]
# Out:
#         TotalWorkingYears  Age
# 1                      25   18
# 10                     29   20
# 14                     33   23
# 17                     37   30
# 38                     36   26
# ...                   ...  ...
# 999939                 29   19
# 999957                 27   27
# 999965                 38   34
# 999975                 29   22
# 999996                 32   24
#
# [125925 rows x 2 columns]

# %% [markdown]
# Observation: From the above output we can observe that even though the employee Age is 18, the employee working for 25 years like this there are 112539 rows that shows impossible relation between them.So we can drop them.

# %%
df.drop(df[df['TotalWorkingYears'] >= df['Age']].index,inplace = True)

# %%
df.shape
# Out:
# (839380, 31)

# %%
df.groupby(["TotalWorkingYears","YearsAtCompany","YearsSinceLastPromotion","Age"]).size().reset_index().tail(10)
# Out:
#         TotalWorkingYears  YearsAtCompany  YearsSinceLastPromotion  Age  0
# 224838                 40              40                       39   48  1
# 224839                 40              40                       39   54  1
# 224840                 40              40                       39   59  1
# 224841                 40              40                       39   60  1
# 224842                 40              40                       40   43  1
# 224843                 40              40                       40   51  1
# 224844                 40              40                       40   54  1
# 224845                 40              40                       40   57  2
# 224846                 40              40                       40   59  1
# 224847                 40              40                       40   60  1

# %% [markdown]
# Observation:
# From the above output we can observe that the employee age is 43 but the employee is working for 40 years that means an employee started working since the employee was 3 years old that is impossible.At least a employee age should be 16 to start doing a job,so we can drop them.

# %%
df.drop(df[(df['Age']-df['TotalWorkingYears'])<=16].index,inplace = True)

# %%
df.groupby(["TotalWorkingYears","YearsAtCompany","YearsSinceLastPromotion","Age"]).size().reset_index().tail(10)
# Out:
#         TotalWorkingYears  YearsAtCompany  YearsSinceLastPromotion  Age  0
# 113807                 40              40                       35   59  1
# 113808                 40              40                       36   60  1
# 113809                 40              40                       37   57  1
# 113810                 40              40                       37   60  1
# 113811                 40              40                       38   59  1
# 113812                 40              40                       39   59  1
# 113813                 40              40                       39   60  1
# 113814                 40              40                       40   57  2
# 113815                 40              40                       40   59  1
# 113816                 40              40                       40   60  1

# %%
df.shape
# Out:
# (546221, 31)

# %% [markdown]
# After dropping all the unimportant data the final shape of our dataset is 546221 rows and 31 columns.

# %%
df
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        58        No  Travel_Frequently        200                Hardware
# 4        35        No      Travel_Rarely        711  Research & Development
# 7        37        No         Non-Travel       1077         Human Resources
# 9        34       Yes  Travel_Frequently       1199                Hardware
# 11       48        No      Travel_Rarely        184         Human Resources
# ...     ...       ...                ...        ...                     ...
# 999992   20        No  Travel_Frequently       1472  Research & Development
# 999993   60       Yes  Travel_Frequently       1290                 Support
# 999994   51        No         Non-Travel       1265                Hardware
# 999997   55        No         Non-Travel       1298                 Support
# 999998   44       Yes         Non-Travel       1065  Research & Development
#
#         DistanceFromHome  Education    EducationField  \
# 0                     13          5     Life Sciences
# 4                     28          4  Technical Degree
# 7                     16          5             Other
# 9                     10          2           Medical
# 11                    34          3             Other
# ...                  ...        ...               ...
# 999992                41          3         Marketing
# 999993                 9          5         Marketing
# 999994                50          3             Other
# 999997                33          5   Human Resources
# 999998                34          3   Human Resources
#
#         EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                             1    Male          33               4         5
# 4                             3    Male          90               1         5
# 7                             3  Female         142               2         3
# 9                             2    Male         197               2         1
# 11                            3    Male         123               1         3
# ...                         ...     ...         ...             ...       ...
# 999992                        1    Male         200               3         4
# 999993                        3  Female         176               4         3
# 999994                        4  Female         154               2         3
# 999997                        1  Female         142               1         3
# 999998                        4  Female         102               2         1
#
#                           JobRole  JobSatisfaction MaritalStatus  \
# 0                 Sales Executive                4       Married
# 4              Research Scientist                1        Single
# 7                         Manager                2        Single
# 9                         Manager                4      Divorced
# 11                Human Resources                1       Married
# ...                           ...              ...           ...
# 999992                    Manager                4        Single
# 999993                    Manager                1      Divorced
# 999994  Healthcare Representative                1       Married
# 999997            Sales Executive                3        Single
# 999998  Healthcare Representative                3       Married
#
#         MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0               17288       224744                   6       No
# 4               41000       615000                   6      Yes
# 7               28591       114364                   3       No
# 9               22968       275616                   2       No
# 11              16527       413175                   1      Yes
# ...               ...          ...                 ...      ...
# 999992           4627         4627                   8       No
# 999993          25823       258230                   0      Yes
# 999994          12158       218844                   0       No
# 999997          19790       316640                   5       No
# 999998           9736        48680                   7      Yes
#
#         PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                      34                  2                         2
# 4                      47                  4                         4
# 7                      22                  3                         3
# 9                       2                  1                         4
# 11                     14                  2                         4
# ...                   ...                ...                       ...
# 999992                 11                  1                         1
# 999993                 16                  3                         1
# 999994                  2                  3                         3
# 999997                 26                  3                         4
# 999998                 25                  3                         3
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                      4                 40                      3
# 4                      3                  1                      1
# 7                      2                  6                      1
# 9                      1                  7                      4
# 11                     2                 17                      6
# ...                  ...                ...                    ...
# 999992                 1                  2                      4
# 999993                 1                 31                      3
# 999994                 4                 15                      2
# 999997                 1                 29                      4
# 999998                 4                 20                      2
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                     4              31                  28
# 4                     4               1                   1
# 7                     1               3                   2
# 9                     3               6                   3
# 11                    2              11                   5
# ...                 ...             ...                 ...
# 999992                2               1                   1
# 999993                1              17                  12
# 999994                2              12                   6
# 999997                4              28                  19
# 999998                3               2                   2
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# 0                             1                    29
# 4                             1                     1
# 7                             3                     2
# 9                             5                     3
# 11                            6                     6
# ...                         ...                   ...
# 999992                        1                     1
# 999993                       17                    13
# 999994                        1                    10
# 999997                       16                    26
# 999998                        1                     2
#
# [546221 rows x 31 columns]

# %% [markdown]
# ### Running the AutoML to select the best algorithm

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Pearson Correlation

# %%
plt.figure(figsize = (40,30))
sb.heatmap(df.corr(), annot = True,vmin =-1,vmax =1)
# Out:
# <AxesSubplot:>

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(df,0.55)
print(corr_features)
print(len(set(corr_features)))
# Out:
# {'YearsInCurrentRole', 'MonthlyRate', 'YearsWithCurrManager', 'YearsAtCompany', 'YearsSinceLastPromotion'}
# 5

# %% [markdown]
# By using "YearsAtCompany" column we will create another feature "Attrition_within_a_year" so that's why we are not dropping that column.In a heatmap we can see that "YearsInCurrentRole" and "YearsSinceLastPromotion" got the correlation value 0.58 so we will drop "YearsInCurrentRole".

# %%
df.drop(['MonthlyRate','YearsInCurrentRole','YearsWithCurrManager'],inplace = True,axis = 1)

# %%
df.shape
# Out:
# (546221, 28)

# %%
df.to_csv("df_automl.csv",index = False)

# %% [markdown]
# ## One Hot Encoding

# %%
df['Attrition'] = np.where(df['Attrition'] == 'Yes',1,0)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.shape
# Out:
# (546221, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 546221 entries, 0 to 999998
# Data columns (total 46 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Age                                546221 non-null  int64
#  1   Attrition                          546221 non-null  int32
#  2   DailyRate                          546221 non-null  int64
#  3   DistanceFromHome                   546221 non-null  int64
#  4   Education                          546221 non-null  int64
#  5   EnvironmentSatisfaction            546221 non-null  int64
#  6   HourlyRate                         546221 non-null  int64
#  7   JobInvolvement                     546221 non-null  int64
#  8   JobLevel                           546221 non-null  int64
#  9   JobSatisfaction                    546221 non-null  int64
#  10  MonthlyIncome                      546221 non-null  int64
#  11  NumCompaniesWorked                 546221 non-null  int64
#  12  PercentSalaryHike                  546221 non-null  int64
#  13  PerformanceRating                  546221 non-null  int64
#  14  RelationshipSatisfaction           546221 non-null  int64
#  15  StockOptionLevel                   546221 non-null  int64
#  16  TotalWorkingYears                  546221 non-null  int64
#  17  TrainingTimesLastYear              546221 non-null  int64
#  18  WorkLifeBalance                    546221 non-null  int64
#  19  YearsAtCompany                     546221 non-null  int64
#  20  YearsSinceLastPromotion            546221 non-null  int64
#  21  BusinessTravel_Travel_Frequently   546221 non-null  uint8
#  22  BusinessTravel_Travel_Rarely       546221 non-null  uint8
#  23  Department_Human Resources         546221 non-null  uint8
#  24  Department_Research & Development  546221 non-null  uint8
#  25  Department_Sales                   546221 non-null  uint8
#  26  Department_Software                546221 non-null  uint8
#  27  Department_Support                 546221 non-null  uint8
#  28  EducationField_Life Sciences       546221 non-null  uint8
#  29  EducationField_Marketing           546221 non-null  uint8
#  30  EducationField_Medical             546221 non-null  uint8
#  31  EducationField_Other               546221 non-null  uint8
#  32  EducationField_Technical Degree    546221 non-null  uint8
#  33  Gender_Male                        546221 non-null  uint8
#  34  JobRole_Healthcare Representative  546221 non-null  uint8
#  35  JobRole_Human Resources            546221 non-null  uint8
#  36  JobRole_Laboratory Technician      546221 non-null  uint8
#  37  JobRole_Manager                    546221 non-null  uint8
#  38  JobRole_Manufacturing Director     546221 non-null  uint8
#  39  JobRole_Research Director          546221 non-null  uint8
#  40  JobRole_Research Scientist         546221 non-null  uint8
#  41  JobRole_Sales Executive            546221 non-null  uint8
#  42  JobRole_Sales Representative       546221 non-null  uint8
#  43  MaritalStatus_Married              546221 non-null  uint8
#  44  MaritalStatus_Single               546221 non-null  uint8
#  45  OverTime_Yes                       546221 non-null  uint8
# dtypes: int32(1), int64(20), uint8(25)
# memory usage: 102.6 MB

# %% [markdown]
# ## Feature Scaling(Normalization)

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
for i in df.columns:
    df[i] = scaling.fit_transform(df[[i]])

# %%
df
# Out:
#              Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0       0.952381        0.0   0.071429          0.244898       1.00
# 4       0.404762        0.0   0.436429          0.551020       0.75
# 7       0.452381        0.0   0.697857          0.306122       1.00
# 9       0.380952        1.0   0.785000          0.183673       0.25
# 11      0.714286        0.0   0.060000          0.673469       0.50
# ...          ...        ...        ...               ...        ...
# 999992  0.047619        0.0   0.980000          0.816327       0.50
# 999993  1.000000        1.0   0.850000          0.163265       1.00
# 999994  0.785714        0.0   0.832143          1.000000       0.50
# 999997  0.880952        0.0   0.855714          0.653061       1.00
# 999998  0.619048        1.0   0.689286          0.673469       0.50
#
#         EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                      0.000000    0.017647        1.000000      1.00
# 4                      0.666667    0.352941        0.000000      1.00
# 7                      0.666667    0.658824        0.333333      0.50
# 9                      0.333333    0.982353        0.333333      0.00
# 11                     0.666667    0.547059        0.000000      0.50
# ...                         ...         ...             ...       ...
# 999992                 0.000000    1.000000        0.666667      0.75
# 999993                 0.666667    0.858824        1.000000      0.50
# 999994                 1.000000    0.729412        0.333333      0.50
# 999997                 0.000000    0.658824        0.000000      0.50
# 999998                 1.000000    0.423529        0.333333      0.00
#
#         JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0              1.000000       0.325767               0.750           0.693878
# 4              0.000000       0.800016               0.750           0.959184
# 7              0.333333       0.551831               0.375           0.448980
# 9              1.000000       0.439369               0.250           0.040816
# 11             0.000000       0.310546               0.125           0.285714
# ...                 ...            ...                 ...                ...
# 999992         1.000000       0.072541               1.000           0.224490
# 999993         0.000000       0.496470               0.000           0.326531
# 999994         0.000000       0.223164               0.000           0.040816
# 999997         0.666667       0.375808               0.625           0.530612
# 999998         0.666667       0.174723               0.875           0.510204
#
#         PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                0.333333                  0.333333          1.000000
# 4                1.000000                  1.000000          0.666667
# 7                0.666667                  0.666667          0.333333
# 9                0.000000                  1.000000          0.000000
# 11               0.333333                  1.000000          0.333333
# ...                   ...                       ...               ...
# 999992           0.000000                  0.000000          0.000000
# 999993           0.666667                  0.000000          0.000000
# 999994           0.666667                  0.666667          1.000000
# 999997           0.666667                  1.000000          0.000000
# 999998           0.666667                  0.666667          1.000000
#
#         TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                1.000000                    0.4         1.000000
# 4                0.000000                    0.0         1.000000
# 7                0.128205                    0.0         0.000000
# 9                0.153846                    0.6         0.666667
# 11               0.410256                    1.0         0.333333
# ...                   ...                    ...              ...
# 999992           0.025641                    0.6         0.333333
# 999993           0.769231                    0.4         0.000000
# 999994           0.358974                    0.2         0.333333
# 999997           0.717949                    0.6         1.000000
# 999998           0.487179                    0.2         0.666667
#
#         YearsAtCompany  YearsSinceLastPromotion  \
# 0             0.769231                 0.000000
# 4             0.000000                 0.000000
# 7             0.051282                 0.051282
# 9             0.128205                 0.102564
# 11            0.256410                 0.128205
# ...                ...                      ...
# 999992        0.000000                 0.000000
# 999993        0.410256                 0.410256
# 999994        0.282051                 0.000000
# 999997        0.692308                 0.384615
# 999998        0.025641                 0.000000
#
#         BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                    1.0                           0.0
# 4                                    0.0                           1.0
# 7                                    0.0                           0.0
# 9                                    1.0                           0.0
# 11                                   0.0                           1.0
# ...                                  ...                           ...
# 999992                               1.0                           0.0
# 999993                               1.0                           0.0
# 999994                               0.0                           0.0
# 999997                               0.0                           0.0
# 999998                               0.0                           0.0
#
#         Department_Human Resources  Department_Research & Development  \
# 0                              0.0                                0.0
# 4                              0.0                                1.0
# 7                              1.0                                0.0
# 9                              0.0                                0.0
# 11                             1.0                                0.0
# ...                            ...                                ...
# 999992                         0.0                                1.0
# 999993                         0.0                                0.0
# 999994                         0.0                                0.0
# 999997                         0.0                                0.0
# 999998                         0.0                                1.0
#
#         Department_Sales  Department_Software  Department_Support  \
# 0                    0.0                  0.0                 0.0
# 4                    0.0                  0.0                 0.0
# 7                    0.0                  0.0                 0.0
# 9                    0.0                  0.0                 0.0
# 11                   0.0                  0.0                 0.0
# ...                  ...                  ...                 ...
# 999992               0.0                  0.0                 0.0
# 999993               0.0                  0.0                 1.0
# 999994               0.0                  0.0                 0.0
# 999997               0.0                  0.0                 1.0
# 999998               0.0                  0.0                 0.0
#
#         EducationField_Life Sciences  EducationField_Marketing  \
# 0                                1.0                       0.0
# 4                                0.0                       0.0
# 7                                0.0                       0.0
# 9                                0.0                       0.0
# 11                               0.0                       0.0
# ...                              ...                       ...
# 999992                           0.0                       1.0
# 999993                           0.0                       1.0
# 999994                           0.0                       0.0
# 999997                           0.0                       0.0
# 999998                           0.0                       0.0
#
#         EducationField_Medical  EducationField_Other  \
# 0                          0.0                   0.0
# 4                          0.0                   0.0
# 7                          0.0                   1.0
# 9                          1.0                   0.0
# 11                         0.0                   1.0
# ...                        ...                   ...
# 999992                     0.0                   0.0
# 999993                     0.0                   0.0
# 999994                     0.0                   1.0
# 999997                     0.0                   0.0
# 999998                     0.0                   0.0
#
#         EducationField_Technical Degree  Gender_Male  \
# 0                                   0.0          1.0
# 4                                   1.0          1.0
# 7                                   0.0          0.0
# 9                                   0.0          1.0
# 11                                  0.0          1.0
# ...                                 ...          ...
# 999992                              0.0          1.0
# 999993                              0.0          0.0
# 999994                              0.0          0.0
# 999997                              0.0          0.0
# 999998                              0.0          0.0
#
#         JobRole_Healthcare Representative  JobRole_Human Resources  \
# 0                                     0.0                      0.0
# 4                                     0.0                      0.0
# 7                                     0.0                      0.0
# 9                                     0.0                      0.0
# 11                                    0.0                      1.0
# ...                                   ...                      ...
# 999992                                0.0                      0.0
# 999993                                0.0                      0.0
# 999994                                1.0                      0.0
# 999997                                0.0                      0.0
# 999998                                1.0                      0.0
#
#         JobRole_Laboratory Technician  JobRole_Manager  \
# 0                                 0.0              0.0
# 4                                 0.0              0.0
# 7                                 0.0              1.0
# 9                                 0.0              1.0
# 11                                0.0              0.0
# ...                               ...              ...
# 999992                            0.0              1.0
# 999993                            0.0              1.0
# 999994                            0.0              0.0
# 999997                            0.0              0.0
# 999998                            0.0              0.0
#
#         JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                                  0.0                        0.0
# 4                                  0.0                        0.0
# 7                                  0.0                        0.0
# 9                                  0.0                        0.0
# 11                                 0.0                        0.0
# ...                                ...                        ...
# 999992                             0.0                        0.0
# 999993                             0.0                        0.0
# 999994                             0.0                        0.0
# 999997                             0.0                        0.0
# 999998                             0.0                        0.0
#
#         JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                              0.0                      1.0
# 4                              1.0                      0.0
# 7                              0.0                      0.0
# 9                              0.0                      0.0
# 11                             0.0                      0.0
# ...                            ...                      ...
# 999992                         0.0                      0.0
# 999993                         0.0                      0.0
# 999994                         0.0                      0.0
# 999997                         0.0                      1.0
# 999998                         0.0                      0.0
#
#         JobRole_Sales Representative  MaritalStatus_Married  \
# 0                                0.0                    1.0
# 4                                0.0                    0.0
# 7                                0.0                    0.0
# 9                                0.0                    0.0
# 11                               0.0                    1.0
# ...                              ...                    ...
# 999992                           0.0                    0.0
# 999993                           0.0                    0.0
# 999994                           0.0                    1.0
# 999997                           0.0                    0.0
# 999998                           0.0                    1.0
#
#         MaritalStatus_Single  OverTime_Yes
# 0                        0.0           0.0
# 4                        1.0           1.0
# 7                        1.0           0.0
# 9                        0.0           0.0
# 11                       0.0           1.0
# ...                      ...           ...
# 999992                   1.0           0.0
# 999993                   0.0           1.0
# 999994                   0.0           0.0
# 999997                   1.0           0.0
# 999998                   0.0           1.0
#
# [546221 rows x 46 columns]

# %%
df.to_csv('Emp_Model_df.csv',index = False)
